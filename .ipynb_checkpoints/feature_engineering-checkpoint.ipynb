# %%
# _*_ coding: utf-8 _*_
# @Time: 2021/11/29 24:17 
# @Author: yuyongsheng
# @Software: PyCharm
# @Description: 上海六院甲氨蝶呤：3. 特征工程

# %%
# 导入程序包
import pymysql as MySQLDB
import pandas as pd
import numpy as np

import re
import sys
import os
project_path = os.getcwd()

# %% [markdown]
# # 特征清洗

# %%
df_model=pd.read_excel(project_path+'/data/processed_data/df_11.4_人工删除无意义列.xlsx')
if 'Unnamed: 0' in df_model.columns:
    df_model = df_model.drop(['Unnamed: 0'], axis=1)

# %%
df_model[[ 'RBC平均容量', 'RBC平均血红量', 'RBC血红浓度']].corr()
# Out:
#            RBC平均容量  RBC平均血红量   RBC血红浓度
# RBC平均容量   1.000000  0.866762 -0.054342
# RBC平均血红量  0.866762  1.000000  0.448312
# RBC血红浓度  -0.054342  0.448312  1.000000

# %% [markdown]
# ## 数据转换

# %%
df_model['gender'] = df_model['gender'].str.replace(' ','').apply(lambda x: 1 if x == '男' else 0)

# %% [markdown]
# ## 删除无关特征

# %%
df_model.columns
# Out:
# Index(['patient_id', 'case_no', 'drug_name', '日剂量', 'start_datetime',
#        'end_datetime', 'gender', 'age', '血红蛋白_before', '血红蛋白_3d', '白细胞_before',
#        '白细胞_3d', '粒细胞_before', '血小板_before', '血小板_3d', '血红蛋白_before_B',
#        '血红蛋白_3d_B', '白细胞_before_B', '白细胞_3d_B', '粒细胞_before_B', '血小板_before_B',
#        '血小板_3d_B', 'bmd_before', 'bmd_3d', 'bmd_7d', 'bmd_14d', 'bmd_time',
#        'bmd_label', 'MTX_tdm_24h', 'MTX_tdm_48h', 'MTX_tdm_72h', '吸烟史', '饮酒史',
#        '高血压', '糖尿病', '肝炎', '多柔比星', '异环磷酰胺', '顺铂', '依托泊苷', '多柔比星脂质体', '头孢类',
#        '促红素', '吡柔吡星', '抗凝血', '谷胱甘肽', '异甘草酸镁', '地塞米松磷酸钠', '托烷司琼', '甘草酸苷',
#        '长春新碱', '多烯磷脂酰', '甲氨蝶呤+多柔比星', '甲氨蝶呤+多柔比星脂质体', '甲氨蝶呤+顺铂', '甲氨蝶呤+异环磷酰胺',
#        '甲氨蝶呤+依托泊苷', '甲氨蝶呤+多柔比星+顺铂', '甲氨蝶呤+多柔比星+异环磷酰胺', '甲氨蝶呤+多柔比星+依托泊苷',
#        '甲氨蝶呤+多柔比星脂质体+顺铂', '甲氨蝶呤+多柔比星脂质体+异环磷酰胺', '甲氨蝶呤+多柔比星脂质体+依托泊苷',
#        '甲氨蝶呤+顺铂+异环磷酰胺', '甲氨蝶呤+顺铂+依托泊苷', '甲氨蝶呤+异环磷酰胺+依托泊苷',
#        '甲氨蝶呤+多柔比星+顺铂+异环磷酰胺', '甲氨蝶呤+多柔比星+顺铂+依托泊苷', '甲氨蝶呤+多柔比星+异环磷酰胺+依托泊苷',
#        '甲氨蝶呤+多柔比星脂质体+顺铂+异环磷酰胺', '甲氨蝶呤+多柔比星脂质体+顺铂+依托泊苷',
#        '甲氨蝶呤+多柔比星脂质体+异环磷酰胺+依托泊苷', '甲氨蝶呤+顺铂+异环磷酰胺+依托泊苷',
#        '甲氨蝶呤+多柔比星+顺铂+异环磷酰胺+依托泊苷', '甲氨蝶呤+多柔比星脂质体+顺铂+异环磷酰胺+依托泊苷', 'group',
#        'RBC平均容量', 'RBC平均血红量', 'RBC血红浓度', 'γ-谷氨酰酶(干式)', '中性细胞百分比', '中性细胞绝对值',
#        '乳酸脱氢酶(干式)', '单核细胞百分比', '单核细胞绝对值', '嗜碱性细胞百分比', '嗜碱性细胞绝对值', '嗜酸性细胞百分比',
#        '嗜酸性细胞绝对值', '总胆红素(干式)', '总蛋白(干式)', '淋巴细胞百分比', '淋巴细胞绝对值', '白蛋白(干式)',
#        '碱性磷酸酶(干式)', '红细胞', '红细胞分布宽度', '肌酐(干式)', '谷丙转氨酶(干式)', '谷草转氨酶(干式)'],
#       dtype='object')

# %%
# 删除无关特征
df_model=df_model.drop(['patient_id','case_no','drug_name','start_datetime','end_datetime','group','bmd_time'],axis=1)

# %%
# 删除目标变强强相关列
del df_model['bmd_before']
del df_model['bmd_3d']
del df_model['bmd_7d']
del df_model['bmd_14d']

df_model=df_model.drop(['血红蛋白_before','血红蛋白_3d','白细胞_before','白细胞_3d','粒细胞_before','血小板_before','血小板_3d',
                '血红蛋白_before_B','血红蛋白_3d_B','白细胞_before_B','白细胞_3d_B','粒细胞_before_B','血小板_before_B','血小板_3d_B'],axis=1)

# %% [markdown]
# ## 删除缺失超过50%的特征

# %%
# 删除缺失超过50%的其他指标
for i in df_model.columns:
    if df_model[i].isnull().sum()/df_model.shape[0] >= 0.5:
        print(i)
        del df_model[i]

# %%
print(df_model.shape)  # (106,101)
# Out:
# (718, 75)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.3_删除缺失超过50%.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 删除分类极不平衡的特征

# %%
# 保护目标变量、tdm数据
for i in df_model.columns[8:]:
    if df_model[i].nunique() < 2:
        del df_model[i]
        continue
    if df_model[i].nunique() == 2:
        # 如果分类变量中某一变量的占比超过90%，则删除该指标
        num_1 = df_model[i].value_counts()  # df一列中不同变量的数目
        num_2 = num_1.div(df_model.shape[0])  # div除法，所有元素都除以相同数值
        num_3 = num_2.max()  # 取出最大值
        if num_3 >= 0.9:
            print(i)
            del df_model[i]
# Out:
# 饮酒史
# 高血压
# 糖尿病
# 肝炎
# 异环磷酰胺
# 顺铂
# 头孢类
# 促红素
# 抗凝血
# 地塞米松磷酸钠
# 甲氨蝶呤+顺铂
# 甲氨蝶呤+异环磷酰胺

# %%
print(df_model.shape)
# Out:
# (718, 38)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.4_删除分类极不平衡.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 过滤异常值

# %%
# 过滤异常值，大于正常值超过100倍！
for i in df_model.columns[8:]:
    # 测试特征是否存在异常值
    median_value= max(df_model[i].median(),1)
    max_value = df_model[i].max()
    if max_value > 100 * median_value:
        print(i)
    df_model[i]=df_model[i].apply(lambda x: np.nan if x<0 or x!=x else 100*median_value if float(x) > 100*median_value else x)
# Out:
# 红细胞

# %%
print(df_model.shape)
# Out:
# (718, 38)

# %%
df_model.columns
# Out:
# Index(['日剂量', 'gender', 'age', 'bmd_label', 'MTX_tdm_24h', 'MTX_tdm_48h',
#        'MTX_tdm_72h', '吸烟史', '谷胱甘肽', '异甘草酸镁', '托烷司琼', '甘草酸苷', '长春新碱', '多烯磷脂酰',
#        'RBC平均容量', 'RBC平均血红量', 'RBC血红浓度', 'γ-谷氨酰酶(干式)', '中性细胞百分比', '中性细胞绝对值',
#        '乳酸脱氢酶(干式)', '单核细胞百分比', '单核细胞绝对值', '嗜碱性细胞百分比', '嗜碱性细胞绝对值', '嗜酸性细胞百分比',
#        '嗜酸性细胞绝对值', '总胆红素(干式)', '总蛋白(干式)', '淋巴细胞百分比', '淋巴细胞绝对值', '白蛋白(干式)',
#        '碱性磷酸酶(干式)', '红细胞', '红细胞分布宽度', '肌酐(干式)', '谷丙转氨酶(干式)', '谷草转氨酶(干式)'],
#       dtype='object')

# %%
# 保存特征清洗
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_1_特征清洗.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# # 显著性分析

# %%
discrete_col=['gender','吸烟史','谷胱甘肽','异甘草酸镁','托烷司琼','甘草酸苷','长春新碱','多烯磷脂酰']
continuous_col=[x for x in df_model.columns if x not in discrete_col]
continuous_col.remove('bmd_label')

# %% [markdown]
# ## 分类变量显著性分析

# %%
# 二分类卡方检验
from scipy.stats import chi2_contingency
feature_list=[]
y_list=[]
t_list=[]
p_list=[]
sig_list=[]
for i in discrete_col:
    print(i)
    result = chi2_contingency(pd.crosstab(df_model['bmd_label'],df_model[i]))
    t,p=result[0:2]
    t=round(t,2)
    p=round(p,3)
    feature_list.append(i)
    y_list.append('卡方检验')
    t_list.append(t)
    p_list.append(p)
    if p <=0.05:
        sig='显著'
    else:
        sig='不显著'
    sig_list.append(sig)
# Out:
# gender
# 吸烟史
# 谷胱甘肽
# 异甘草酸镁
# 托烷司琼
# 甘草酸苷
# 长春新碱
# 多烯磷脂酰

# %%
df_result_dis=pd.DataFrame({'特征':feature_list,
                        '检验指标':y_list,
                        't值':t_list,
                        'p值':p_list,
                        '显著性结果':sig_list})

# %%
# psm分类变量显著性检验
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_2.1_分类变量显著性检验.xlsx')
df_result_dis.to_excel(writer)
writer.save()

# %%
len(feature_list)
# Out:
# 8

# %% [markdown]
# ## 连续变量显著性分析

# %%
from scipy.stats import kstest,shapiro
##检验是否正态
def norm_test(data):
    if len(data) > 30:
        norm, p = kstest(data, 'norm')
    else:
        norm, p = shapiro(data)
    #print(t,p)
    if p>=0.05:
        return True
    else:
        return False

# %%
import scipy.stats as st
# 连续变量的显著性检验
def test2(data_b, data_p):
    if norm_test(data_b) and norm_test(data_p):
        x = 1
        y = '独立样本T检验'
        t, p = st.ttest_ind(list(data_b),list(data_p), nan_policy='omit')
    else:
        x = 0
        y = 'Mann-Whitney U检验'
        t,p = st.mannwhitneyu(list(data_b),list(data_p))
    return x,y,t,p

# %%
def sig_test(df_high,df_low,list1):

    feature_list=[]  # 特征列表
    y_list=[]  # 显著性检验方法
    t_list=[]  # 统计量
    p_list=[]  # p值
    result_list=[]  # 是否显著
    high_mean_list=[]
    low_mean_list=[]

    for i in list1:
        print(i)
        # 高剂量组统计
        df_high_nt=df_high[df_high[i].notnull()]
        data_high=df_high_nt[i]
        high_mean=round(data_high.mean(),2)
        
        df_low_nt=df_low[df_low[i].notnull()]
        data_low=df_low_nt[i]
        low_mean=round(data_low.mean(),2)

        # 计算高低剂量组显著性差异
        if data_high.shape[0] >= 10 and data_low.shape[0]>=10:
            # 连续变量检验
            x,y,t,p = test2(data_high, data_low)
            t=round(t,2)
            p=round(p,3)
            if p <=0.05:
                sig='显著'
            else:
                sig='不显著'
            # 显著性 
            feature_list.append(i)
            y_list.append(y)
            t_list.append(t)
            p_list.append(p)
            result_list.append(sig)
            high_mean_list.append(high_mean)
            low_mean_list.append(low_mean)

    df_result=pd.DataFrame({'特征':feature_list,
                            '高剂量均值':high_mean_list,
                            '低剂量均值':low_mean_list,
                            '检验指标':y_list,
                            't值':t_list,
                            'p值':p_list,
                            '显著性结果':result_list})
    return df_result

# %%
# 提取甲氨蝶呤不同标签
df_MTX_high = df_model[df_model['bmd_label']==1]
df_MTX_low = df_model[df_model['bmd_label']==0]

# %%
# 甲氨蝶呤高低剂量组PSM控制变量统计和显著性检验
df_MTX_PSM_sig = sig_test(df_MTX_high,df_MTX_low,continuous_col)
df_MTX_PSM_sig = df_MTX_PSM_sig.reset_index(drop=True)
# Out:
# 日剂量
# age
# MTX_tdm_24h
# MTX_tdm_48h
# MTX_tdm_72h
# RBC平均容量
# RBC平均血红量
# RBC血红浓度
# γ-谷氨酰酶(干式)
# 中性细胞百分比
# 中性细胞绝对值
# 乳酸脱氢酶(干式)
# 单核细胞百分比
# 单核细胞绝对值
# 嗜碱性细胞百分比
# 嗜碱性细胞绝对值
# 嗜酸性细胞百分比
# 嗜酸性细胞绝对值
# 总胆红素(干式)
# 总蛋白(干式)
# 淋巴细胞百分比
# 淋巴细胞绝对值
# 白蛋白(干式)
# 碱性磷酸酶(干式)
# 红细胞
# 红细胞分布宽度
# 肌酐(干式)
# 谷丙转氨酶(干式)
# 谷草转氨酶(干式)

# %%
# 保存高低剂量组PSM控制变量统计和显著性检验
writer=pd.ExcelWriter(project_path+r'/data/result/feature_engineering/df_2.2_连续变量相关性分析.xlsx')
df_MTX_PSM_sig.to_excel(writer)
writer.save()

# %%
continuous_relate = list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='显著']['特征'])

# %%
list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='不显著']['特征'])
# Out:
# ['日剂量',
#  'age',
#  'MTX_tdm_24h',
#  'MTX_tdm_48h',
#  'MTX_tdm_72h',
#  'RBC平均容量',
#  'RBC平均血红量',
#  'RBC血红浓度',
#  'γ-谷氨酰酶(干式)',
#  '嗜碱性细胞绝对值',
#  '总胆红素(干式)',
#  '碱性磷酸酶(干式)',
#  '红细胞分布宽度',
#  '谷丙转氨酶(干式)']

# %%
# 业务角度需要保留：日剂量、age、MTX_tdm_24h、MTX_tdm_48h、MTX_tdm_72h
continuous_relate.extend(['日剂量','age','MTX_tdm_24h','MTX_tdm_48h','MTX_tdm_72h','RBC平均容量','RBC血红浓度'])

# %%
len(continuous_relate)
# Out:
# 22

# %%
# 提取相关性特征
feature_relate=discrete_col + continuous_relate
# 加入目标变量
feature_relate.insert(0,'bmd_label')
df_model_relate=df_model[feature_relate]

# %%
# 保存显著性分析结果
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_2_显著性清洗.xlsx')
df_model_relate.to_excel(writer)
writer.save()

# %% [markdown]
# # 重要性评分排序

# %%
df_model_relate.shape
# Out:
# (718, 31)

# %%
from sklearn.model_selection import train_test_split

# 划分训练集和测试集，比例为8:2
x = df_model_relate.drop(['bmd_label'],axis=1)
y = df_model_relate['bmd_label']
tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
# 重要性
import catboost,xgboost
model_boost=xgboost.XGBClassifier(max_depth=5,
                                learning_rate=0.01,
                                n_estimators=500,
                                min_child_weight=0.5,
                                eta=0.1,
                                gamma=0.5,
                                reg_lambda=10,
                                subsample=0.5,
                                colsample_bytree=0.8,
                                nthread=4,
                                scale_pos_weight=1)
model_boost.fit(tran_x,tran_y)
importance = model_boost.feature_importances_
print(tran_x.columns)
print(importance)
# Out:
# Index(['gender', '吸烟史', '谷胱甘肽', '异甘草酸镁', '托烷司琼', '甘草酸苷', '长春新碱', '多烯磷脂酰',
#        '中性细胞百分比', '中性细胞绝对值', '乳酸脱氢酶(干式)', '单核细胞百分比', '单核细胞绝对值', '嗜碱性细胞百分比',
#        '嗜酸性细胞百分比', '嗜酸性细胞绝对值', '总蛋白(干式)', '淋巴细胞百分比', '淋巴细胞绝对值', '白蛋白(干式)',
#        '红细胞', '肌酐(干式)', '谷草转氨酶(干式)', '日剂量', 'age', 'MTX_tdm_24h',
#        'MTX_tdm_48h', 'MTX_tdm_72h', 'RBC平均容量', 'RBC血红浓度'],
#       dtype='object')
# [0.02638529 0.02128197 0.03516589 0.06287862 0.04152709 0.0597481
#  0.01910781 0.02832386 0.02174501 0.03712744 0.04362798 0.05029701
#  0.08309329 0.02761939 0.02926641 0.03542112 0.02103227 0.04486332
#  0.02064868 0.02253822 0.03077013 0.02133169 0.06081294 0.01862139
#  0.0263206  0.01998792 0.02240159 0.02419785 0.02488325 0.01897374]

# %%
df_importance= pd.DataFrame(data={'特征':tran_x.columns,'重要性评分':importance})
df_importance['重要性评分']=df_importance['重要性评分'].apply(lambda x: round(x,3))
df_importance=df_importance.sort_values(['重要性评分'],ascending=False)
df_importance=df_importance.reset_index(drop=True)

# %%
df_importance.to_excel(project_path + '/data/result/feature_engineering/df_3_模型重要性评分.xlsx')

# %%
# 筛选重要特征组建建模数据
df_importance_select=df_importance[df_importance['重要性评分']>0]
select_list = list(df_importance_select['特征'])
select_list.insert(0,'bmd_label')

# %%
df_model_importance = df_model_relate[select_list]

# %%
df_model_importance.shape
# Out:
# (718, 31)

# %%
# 保存重要性评分筛选后的建模数据
writer = pd.ExcelWriter(project_path + '/data/result/df_model_data_importance.xlsx')
df_model_importance.to_excel(writer)
writer.save()

# %% [markdown]
# # 逐步向前

# %%
df_model_importance
# Out:
#      bmd_label  单核细胞绝对值  异甘草酸镁  谷草转氨酶(干式)  甘草酸苷  单核细胞百分比  淋巴细胞百分比  乳酸脱氢酶(干式)  \
# 0            0      0.1      1       45.0     0      3.0     20.9      471.0
# 1            0      0.1      1       46.0     0      3.0     22.4      511.0
# 2            1      0.5      0       69.0     0      3.9      5.7      717.0
# 3            1      0.2      0       86.0     0      4.2     16.4      491.0
# 4            0      0.2      0       33.0     1      5.6      7.0      381.0
# ..         ...      ...    ...        ...   ...      ...      ...        ...
# 713          0      0.2      1       18.0     0      1.7      8.0      788.0
# 714          1      0.4      1       16.0     0     15.1     18.7      388.0
# 715          0      0.1      1       83.0     0      3.1     40.1      605.0
# 716          0      0.1      0       20.0     0      0.6      8.3      559.0
# 717          0      0.1      1       27.0     0      0.2      5.3      462.0
#
#      托烷司琼  中性细胞绝对值  ...  中性细胞百分比  MTX_tdm_48h  总蛋白(干式)  淋巴细胞绝对值  吸烟史  肌酐(干式)  \
# 0       1      3.5  ...     75.0         3.48     64.0      1.0  0.0    62.0
# 1       0      2.9  ...     73.8         0.10     64.0      0.9  0.0    35.0
# 2       0     10.6  ...     89.8         4.85     66.0      0.7  0.0    57.0
# 3       0      2.9  ...     78.4         3.79     62.0      0.6  0.0    39.0
# 4       0      3.1  ...     86.8         3.74     63.0      0.3  0.0    61.0
# ..    ...      ...  ...      ...          ...      ...      ...  ...     ...
# 713     0     11.0  ...     90.3         0.10     71.0      1.0  0.0    49.0
# 714     1      1.6  ...     62.8         1.13     59.0      0.5  0.0    66.0
# 715     1      1.7  ...     53.7         0.10     65.0      1.3  0.0    42.0
# 716     0      7.1  ...     89.0          NaN     60.0      0.7  0.0    33.0
# 717     0     18.4  ...     92.9         1.01     61.0      1.1  0.0    66.0
#
#      MTX_tdm_24h   日剂量  长春新碱  RBC血红浓度
# 0          28.32  20.0     0    334.0
# 1           6.90  11.0     0    356.0
# 2          14.83  21.0     0    339.0
# 3           9.21  13.0     0    338.0
# 4          57.57  16.0     0    345.0
# ..           ...   ...   ...      ...
# 713         0.90  18.0     0    341.0
# 714        14.30  16.5     0    331.0
# 715         5.66  12.4     0    345.0
# 716         0.10  16.0     0    326.0
# 717        14.35  18.0     0    345.0
#
# [718 rows x 31 columns]

# %% [markdown]
# ## 插补数据

# %%
# 使用随机森林对缺失值进行插补
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
def missing_value_interpolation(df):
    df = df.reset_index(drop=True)
    # 提取存在缺失值的列名
    missing_list = []
    for i in df.columns:
        if df[i].isnull().sum() > 0:
            missing_list.append(i)
    missing_list_copy = missing_list.copy()
    # 用该列未缺失的值训练随机森林，然后用训练好的rf预测缺失值
    for i in range(len(missing_list)):
        name=missing_list[0]
        df_missing = df[missing_list_copy]
        # 将其他列的缺失值用0表示。
        missing_list.remove(name)
        for j in missing_list:
            df_missing[j]=df_missing[j].astype('str').apply(lambda x: 0 if x=='nan' else x)
        df_missing_is = df_missing[df_missing[name].isnull()]
        df_missing_not = df_missing[df_missing[name].notnull()]
        y = df_missing_not[name]
        x = df_missing_not.drop([name],axis=1)
        # 列出参数列表
        tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
        # 进行参数的搜索组合
        grid = GridSearchCV(RandomForestRegressor(),param_grid=tree_grid_parameter,cv=3)
        #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
        #根据已有数据去拟合随机森林模型
        grid.fit(x, y)
        rfr = RandomForestRegressor(n_estimators=grid.best_params_['n_estimators'])
        rfr.fit(x, y)
        #预测缺失值
        predict = rfr.predict(df_missing_is.drop([name],axis=1))
        #填补缺失值
        df.loc[df[name].isnull(),name] = predict
    return df

# %%
df_model_cb=missing_value_interpolation(df_model_importance)

# %%
df_model_cb.shape
# Out:
# (718, 31)

# %% [markdown]
# ## 划分数据集和过采样

# %%
from sklearn.model_selection import train_test_split
# 划分训练集和测试集，比例为8:2
x = df_model_cb.drop(['bmd_label'],axis=1)
y = df_model_cb['bmd_label']

tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
tran_x.shape
# Out:
# (574, 30)

# %%
# 进行过采样
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)

tran_x_sm,tran_y_sm = sm.fit_resample(tran_x,tran_y)

# %%
tran_x_sm.shape[1]
# Out:
# 30

# %% [markdown]
# ##  forward stepwise

# %%
tran_x_sm.columns
# Out:
# Index(['单核细胞绝对值', '异甘草酸镁', '谷草转氨酶(干式)', '甘草酸苷', '单核细胞百分比', '淋巴细胞百分比',
#        '乳酸脱氢酶(干式)', '托烷司琼', '中性细胞绝对值', '嗜酸性细胞绝对值', '谷胱甘肽', '红细胞', '嗜酸性细胞百分比',
#        '多烯磷脂酰', '嗜碱性细胞百分比', 'age', 'gender', 'RBC平均容量', 'MTX_tdm_72h',
#        '白蛋白(干式)', '中性细胞百分比', 'MTX_tdm_48h', '总蛋白(干式)', '淋巴细胞绝对值', '吸烟史',
#        '肌酐(干式)', 'MTX_tdm_24h', '日剂量', '长春新碱', 'RBC血红浓度'],
#       dtype='object')

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestClassifier

r2_max_list=[]
feature_max_list=[]
for i in range(1,tran_x_sm.shape[1]+1):
    # 津源xgboost模型
    sfs = SFS(RandomForestClassifier(n_estimators=500,
                                    criterion='entropy',
                                    max_depth=5,
                                    n_jobs=-1,
                                    random_state=3),
              n_jobs=-1, # 并行使用的进程数，默认1个，如果设置为-1，该值为总的核数
              k_features=i,
             forward=True,
             floating=False,  
             verbose=2,  # 显示输出的一些参数，默认为0不输出
             scoring='f1',  # 'f1' for binary targets
             cv=3)  # cv交叉验证

    sfs = sfs.fit(tran_x_sm, tran_y_sm)
    # 逐步向前筛选结果，包括特征个数，最优特征组合及其r2
    sfs_result = sfs.subsets_
    df_sfs = pd.DataFrame(sfs_result)
    # 逐步向前结果
    r2_list=list(df_sfs.loc['avg_score'])
    feature_list=list(df_sfs.loc['feature_names'])
    # 保存特征组合
    r2_max_list.append(r2_list)
    feature_max_list.append(feature_list)
#     if i==8:
#         print(datetime.datetime.now())
#         break
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   21.5s finished
#
# [2021-12-13 18:01:22] Features: 1/1 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   19.4s finished
#
# [2021-12-13 18:01:41] Features: 1/2 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s finished
#
# [2021-12-13 18:02:00] Features: 2/2 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.8s finished
#
# [2021-12-13 18:02:19] Features: 1/3 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.3s finished
#
# [2021-12-13 18:02:38] Features: 2/3 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.9s finished
#
# [2021-12-13 18:02:57] Features: 3/3 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   20.7s finished
#
# [2021-12-13 18:03:18] Features: 1/4 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.7s finished
#
# [2021-12-13 18:03:38] Features: 2/4 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.2s finished
#
# [2021-12-13 18:03:57] Features: 3/4 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   18.2s finished
#
# [2021-12-13 18:04:15] Features: 4/4 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   20.0s finished
#
# [2021-12-13 18:04:35] Features: 1/5 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.7s finished
#
# [2021-12-13 18:04:55] Features: 2/5 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.9s finished
#
# [2021-12-13 18:05:14] Features: 3/5 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.8s finished
#
# [2021-12-13 18:05:32] Features: 4/5 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   18.5s finished
#
# [2021-12-13 18:05:51] Features: 5/5 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   19.7s finished
#
# [2021-12-13 18:06:10] Features: 1/6 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.4s finished
#
# [2021-12-13 18:06:30] Features: 2/6 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.8s finished
#
# [2021-12-13 18:06:49] Features: 3/6 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.8s finished
#
# [2021-12-13 18:07:07] Features: 4/6 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.6s finished
#
# [2021-12-13 18:07:24] Features: 5/6 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.4s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.6s finished
#
# [2021-12-13 18:07:42] Features: 6/6 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   19.6s finished
#
# [2021-12-13 18:08:02] Features: 1/7 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   20.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   20.1s finished
#
# [2021-12-13 18:08:22] Features: 2/7 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.7s finished
#
# [2021-12-13 18:08:42] Features: 3/7 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   18.7s finished
#
# [2021-12-13 18:09:01] Features: 4/7 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.0s finished
#
# [2021-12-13 18:09:18] Features: 5/7 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.9s finished
#
# [2021-12-13 18:09:35] Features: 6/7 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   15.1s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:09:50] Features: 7/7 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.9s finished
#
# [2021-12-13 18:10:09] Features: 1/8 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.9s finished
#
# [2021-12-13 18:10:28] Features: 2/8 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   19.7s finished
#
# [2021-12-13 18:10:48] Features: 3/8 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   19.1s finished
#
# [2021-12-13 18:11:07] Features: 4/8 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   16.9s finished
#
# [2021-12-13 18:11:24] Features: 5/8 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.2s finished
#
# [2021-12-13 18:11:41] Features: 6/8 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   14.8s finished
#
# [2021-12-13 18:11:56] Features: 7/8 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.2s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.5s finished
#
# [2021-12-13 18:12:11] Features: 8/8 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.8s finished
#
# [2021-12-13 18:12:30] Features: 1/9 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.5s finished
#
# [2021-12-13 18:12:49] Features: 2/9 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.8s finished
#
# [2021-12-13 18:13:07] Features: 3/9 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.3s finished
#
# [2021-12-13 18:13:25] Features: 4/9 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.2s finished
#
# [2021-12-13 18:13:42] Features: 5/9 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.9s finished
#
# [2021-12-13 18:13:59] Features: 6/9 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:14:14] Features: 7/9 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.1s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.6s finished
#
# [2021-12-13 18:14:29] Features: 8/9 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.6s finished
#
# [2021-12-13 18:14:43] Features: 9/9 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.6s finished
#
# [2021-12-13 18:15:02] Features: 1/10 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s finished
#
# [2021-12-13 18:15:21] Features: 2/10 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s finished
#
# [2021-12-13 18:15:39] Features: 3/10 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.6s finished
#
# [2021-12-13 18:15:56] Features: 4/10 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:16:14] Features: 5/10 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.1s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.9s finished
#
# [2021-12-13 18:16:31] Features: 6/10 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:16:46] Features: 7/10 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.2s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.7s finished
#
# [2021-12-13 18:17:01] Features: 8/10 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.1s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.3s finished
#
# [2021-12-13 18:17:15] Features: 9/10 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.5s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.2s finished
#
# [2021-12-13 18:17:29] Features: 10/10 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.6s finished
#
# [2021-12-13 18:17:48] Features: 1/11 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s finished
#
# [2021-12-13 18:18:07] Features: 2/11 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s finished
#
# [2021-12-13 18:18:25] Features: 3/11 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.4s finished
#
# [2021-12-13 18:18:42] Features: 4/11 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:18:59] Features: 5/11 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.9s finished
#
# [2021-12-13 18:19:16] Features: 6/11 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.0s finished
#
# [2021-12-13 18:19:31] Features: 7/11 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.3s finished
#
# [2021-12-13 18:19:46] Features: 8/11 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.6s finished
#
# [2021-12-13 18:20:01] Features: 9/11 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.3s finished
#
# [2021-12-13 18:20:15] Features: 10/11 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.9s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2021-12-13 18:20:29] Features: 11/11 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.9s finished
#
# [2021-12-13 18:20:48] Features: 1/12 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.7s finished
#
# [2021-12-13 18:21:07] Features: 2/12 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s finished
#
# [2021-12-13 18:21:24] Features: 3/12 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.4s finished
#
# [2021-12-13 18:21:42] Features: 4/12 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.3s finished
#
# [2021-12-13 18:21:59] Features: 5/12 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.9s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.8s finished
#
# [2021-12-13 18:22:16] Features: 6/12 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:22:31] Features: 7/12 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.2s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.6s finished
#
# [2021-12-13 18:22:46] Features: 8/12 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.4s finished
#
# [2021-12-13 18:23:01] Features: 9/12 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.1s finished
#
# [2021-12-13 18:23:15] Features: 10/12 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.7s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.5s finished
#
# [2021-12-13 18:23:28] Features: 11/12 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.5s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.2s finished
#
# [2021-12-13 18:23:42] Features: 12/12 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.9s finished
#
# [2021-12-13 18:24:01] Features: 1/13 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s finished
#
# [2021-12-13 18:24:19] Features: 2/13 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.8s finished
#
# [2021-12-13 18:24:37] Features: 3/13 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.5s finished
#
# [2021-12-13 18:24:55] Features: 4/13 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.4s finished
#
# [2021-12-13 18:25:12] Features: 5/13 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.2s finished
#
# [2021-12-13 18:25:30] Features: 6/13 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:25:45] Features: 7/13 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.1s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.6s finished
#
# [2021-12-13 18:25:59] Features: 8/13 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.4s finished
#
# [2021-12-13 18:26:14] Features: 9/13 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.2s finished
#
# [2021-12-13 18:26:28] Features: 10/13 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.8s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2021-12-13 18:26:42] Features: 11/13 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.4s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.2s finished
#
# [2021-12-13 18:26:55] Features: 12/13 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.0s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   12.8s finished
#
# [2021-12-13 18:27:08] Features: 13/13 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.6s finished
#
# [2021-12-13 18:27:27] Features: 1/14 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s finished
#
# [2021-12-13 18:27:46] Features: 2/14 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.0s finished
#
# [2021-12-13 18:28:04] Features: 3/14 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.6s finished
#
# [2021-12-13 18:28:21] Features: 4/14 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:28:39] Features: 5/14 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.9s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.1s finished
#
# [2021-12-13 18:28:56] Features: 6/14 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.0s finished
#
# [2021-12-13 18:29:11] Features: 7/14 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.5s finished
#
# [2021-12-13 18:29:26] Features: 8/14 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.6s finished
#
# [2021-12-13 18:29:40] Features: 9/14 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.5s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.0s finished
#
# [2021-12-13 18:29:54] Features: 10/14 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   11.0s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2021-12-13 18:30:08] Features: 11/14 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.6s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.3s finished
#
# [2021-12-13 18:30:22] Features: 12/14 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.0s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   13.2s finished
#
# [2021-12-13 18:30:35] Features: 13/14 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.6s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.6s finished
#
# [2021-12-13 18:30:48] Features: 14/14 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.7s finished
#
# [2021-12-13 18:31:06] Features: 1/15 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.4s finished
#
# [2021-12-13 18:31:25] Features: 2/15 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s finished
#
# [2021-12-13 18:31:43] Features: 3/15 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.5s finished
#
# [2021-12-13 18:32:01] Features: 4/15 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:32:18] Features: 5/15 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.0s finished
#
# [2021-12-13 18:32:35] Features: 6/15 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:32:50] Features: 7/15 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.1s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.6s finished
#
# [2021-12-13 18:33:05] Features: 8/15 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.4s finished
#
# [2021-12-13 18:33:19] Features: 9/15 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.1s finished
#
# [2021-12-13 18:33:33] Features: 10/15 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.8s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.7s finished
#
# [2021-12-13 18:33:47] Features: 11/15 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.4s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.4s finished
#
# [2021-12-13 18:34:01] Features: 12/15 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.4s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   12.9s finished
#
# [2021-12-13 18:34:14] Features: 13/15 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.7s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.6s finished
#
# [2021-12-13 18:34:26] Features: 14/15 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    9.7s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   10.7s finished
#
# [2021-12-13 18:34:37] Features: 15/15 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.7s finished
#
# [2021-12-13 18:34:56] Features: 1/16 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.7s finished
#
# [2021-12-13 18:35:15] Features: 2/16 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.6s finished
#
# [2021-12-13 18:35:32] Features: 3/16 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.7s finished
#
# [2021-12-13 18:35:50] Features: 4/16 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.5s finished
#
# [2021-12-13 18:36:08] Features: 5/16 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.4s finished
#
# [2021-12-13 18:36:25] Features: 6/16 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.7s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:36:41] Features: 7/16 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.3s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.7s finished
#
# [2021-12-13 18:36:55] Features: 8/16 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.5s finished
#
# [2021-12-13 18:37:10] Features: 9/16 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.5s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.1s finished
#
# [2021-12-13 18:37:24] Features: 10/16 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.9s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2021-12-13 18:37:38] Features: 11/16 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.6s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.4s finished
#
# [2021-12-13 18:37:52] Features: 12/16 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.1s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   12.7s finished
#
# [2021-12-13 18:38:04] Features: 13/16 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.7s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.8s finished
#
# [2021-12-13 18:38:17] Features: 14/16 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    9.7s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   10.5s finished
#
# [2021-12-13 18:38:28] Features: 15/16 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    6.0s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   10.6s finished
#
# [2021-12-13 18:38:39] Features: 16/16 -- score: 0.9746980773649723[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.9s finished
#
# [2021-12-13 18:38:58] Features: 1/17 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s finished
#
# [2021-12-13 18:39:16] Features: 2/17 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.7s finished
#
# [2021-12-13 18:39:34] Features: 3/17 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.7s finished
#
# [2021-12-13 18:39:52] Features: 4/17 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:40:09] Features: 5/17 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.9s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.8s finished
#
# [2021-12-13 18:40:26] Features: 6/17 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   15.0s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 18:40:41] Features: 7/17 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.3s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.6s finished
#
# [2021-12-13 18:40:56] Features: 8/17 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.5s finished
#
# [2021-12-13 18:41:11] Features: 9/17 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.2s finished
#
# [2021-12-13 18:41:25] Features: 10/17 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.6s finished
#
# [2021-12-13 18:41:39] Features: 11/17 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.6s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.4s finished
#
# [2021-12-13 18:41:52] Features: 12/17 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.2s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   12.6s finished
#
# [2021-12-13 18:42:05] Features: 13/17 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.7s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   13.1s finished
#
# [2021-12-13 18:42:18] Features: 14/17 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    9.6s remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   10.5s finished
#
# [2021-12-13 18:42:29] Features: 15/17 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    5.9s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   10.5s finished
#
# [2021-12-13 18:42:39] Features: 16/17 -- score: 0.9746980773649723[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    5.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   10.2s finished
#
# [2021-12-13 18:42:49] Features: 17/17 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.6s finished
#
# [2021-12-13 18:43:08] Features: 1/18 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.6s finished
#
# [2021-12-13 18:43:27] Features: 2/18 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.1s finished
#
# [2021-12-13 18:43:45] Features: 3/18 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.6s finished
#
# [2021-12-13 18:44:03] Features: 4/18 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.2s finished
#
# [2021-12-13 18:44:20] Features: 5/18 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.8s finished
#
# [2021-12-13 18:44:37] Features: 6/18 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.2s finished
#
# [2021-12-13 18:44:52] Features: 7/18 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.4s finished
#
# [2021-12-13 18:45:07] Features: 8/18 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   13.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.4s finished
#
# [2021-12-13 18:45:21] Features: 9/18 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.0s finished
#
# [2021-12-13 18:45:35] Features: 10/18 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.9s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2021-12-13 18:45:49] Features: 11/18 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.5s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.2s finished
#
# [2021-12-13 18:46:03] Features: 12/18 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.2s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   12.6s finished
#
# [2021-12-13 18:46:15] Features: 13/18 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.8s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.6s finished
#
# [2021-12-13 18:46:28] Features: 14/18 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    9.4s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   10.4s finished
#
# [2021-12-13 18:46:38] Features: 15/18 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    5.8s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   10.5s finished
#
# [2021-12-13 18:46:49] Features: 16/18 -- score: 0.9746980773649723[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    5.8s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   10.1s finished
#
# [2021-12-13 18:46:59] Features: 17/18 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    5.4s remaining:    8.6s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    9.5s finished
#
# [2021-12-13 18:47:09] Features: 18/18 -- score: 0.972883616514773[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   18.6s finished
#
# [2021-12-13 18:47:28] Features: 1/19 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   18.5s finished
#
# [2021-12-13 18:47:46] Features: 2/19 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   17.9s finished
#
# [2021-12-13 18:48:04] Features: 3/19 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.8s finished
#
# [2021-12-13 18:48:22] Features: 4/19 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.1s finished
#
# [2021-12-13 18:48:39] Features: 5/19 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   14.7s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   16.8s finished
#
# ...
#
# [2021-12-13 19:38:58] Features: 5/29 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.4s finished
#
# [2021-12-13 19:39:15] Features: 6/29 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   15.3s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.9s finished
#
# [2021-12-13 19:39:31] Features: 7/29 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.5s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   15.0s finished
#
# [2021-12-13 19:39:46] Features: 8/29 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.4s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.9s finished
#
# [2021-12-13 19:40:01] Features: 9/29 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   14.0s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.6s finished
#
# [2021-12-13 19:40:16] Features: 10/29 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   11.1s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   14.3s finished
#
# [2021-12-13 19:40:31] Features: 11/29 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   11.4s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   14.2s finished
#
# [2021-12-13 19:40:45] Features: 12/29 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.4s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   13.2s finished
#
# [2021-12-13 19:40:58] Features: 13/29 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:   10.0s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   13.1s finished
#
# [2021-12-13 19:41:11] Features: 14/29 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    9.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   10.6s finished
#
# [2021-12-13 19:41:22] Features: 15/29 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    5.9s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   10.8s finished
#
# [2021-12-13 19:41:33] Features: 16/29 -- score: 0.9746980773649723[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    5.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   10.3s finished
#
# [2021-12-13 19:41:44] Features: 17/29 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    5.1s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    9.8s finished
#
# [2021-12-13 19:41:53] Features: 18/29 -- score: 0.972883616514773[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    5.0s remaining:   10.2s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    9.1s finished
#
# [2021-12-13 19:42:03] Features: 19/29 -- score: 0.9755693267738845[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    4.6s remaining:   21.1s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    6.0s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    8.3s finished
#
# [2021-12-13 19:42:11] Features: 20/29 -- score: 0.9737915881983678[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    6.0s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    8.3s finished
#
# [2021-12-13 19:42:19] Features: 21/29 -- score: 0.9747185543423003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    5.0s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    7.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    7.7s finished
#
# [2021-12-13 19:42:27] Features: 22/29 -- score: 0.9746340365800199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    4.9s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.8s finished
#
# [2021-12-13 19:42:33] Features: 23/29 -- score: 0.9728299802157658[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    4.8s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    5.3s finished
#
# [2021-12-13 19:42:39] Features: 24/29 -- score: 0.9728356658672329[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    4.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    4.7s finished
#
# [2021-12-13 19:42:43] Features: 25/29 -- score: 0.9736692062034248[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.2s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.3s finished
#
# [2021-12-13 19:42:48] Features: 26/29 -- score: 0.9756367427256697[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.8s finished
#
# [2021-12-13 19:42:52] Features: 27/29 -- score: 0.9755748821404545[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.4s finished
#
# [2021-12-13 19:42:55] Features: 28/29 -- score: 0.9736952147498332[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.8s finished
#
# [2021-12-13 19:42:58] Features: 29/29 -- score: 0.9719092331768389[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   19.0s finished
#
# [2021-12-13 19:43:17] Features: 1/30 -- score: 0.9016914032231247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   19.3s finished
#
# [2021-12-13 19:43:37] Features: 2/30 -- score: 0.9147936008521561[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   18.5s finished
#
# [2021-12-13 19:43:55] Features: 3/30 -- score: 0.9213310133619812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   17.8s finished
#
# [2021-12-13 19:44:13] Features: 4/30 -- score: 0.9391060061322003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   17.8s finished
#
# [2021-12-13 19:44:31] Features: 5/30 -- score: 0.9517279412721081[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   15.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   17.3s finished
#
# [2021-12-13 19:44:48] Features: 6/30 -- score: 0.9631056065849685[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   14.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   15.1s finished
#
# [2021-12-13 19:45:04] Features: 7/30 -- score: 0.9672826186459519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   14.3s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   14.8s finished
#
# [2021-12-13 19:45:18] Features: 8/30 -- score: 0.972756981580511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.4s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   14.8s finished
#
# [2021-12-13 19:45:33] Features: 9/30 -- score: 0.9710007280397056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.8s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.4s finished
#
# [2021-12-13 19:45:48] Features: 10/30 -- score: 0.9728267578217727[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   11.0s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.9s finished
#
# [2021-12-13 19:46:02] Features: 11/30 -- score: 0.9737230302886027[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.8s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.6s finished
#
# [2021-12-13 19:46:16] Features: 12/30 -- score: 0.9718970005065356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.3s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   13.0s finished
#
# [2021-12-13 19:46:29] Features: 13/30 -- score: 0.9726330532212885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:   10.2s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.7s finished
#
# [2021-12-13 19:46:41] Features: 14/30 -- score: 0.9727135027879908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:   10.0s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   11.1s finished
#
# [2021-12-13 19:46:53] Features: 15/30 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    6.3s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   11.1s finished
#
# [2021-12-13 19:47:04] Features: 16/30 -- score: 0.9746980773649723[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    6.1s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   10.7s finished
#
# [2021-12-13 19:47:15] Features: 17/30 -- score: 0.9727992865386632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    5.6s remaining:    9.0s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    9.9s finished
#
# [2021-12-13 19:47:25] Features: 18/30 -- score: 0.972883616514773[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    5.5s remaining:   11.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   10.2s finished
#
# [2021-12-13 19:47:35] Features: 19/30 -- score: 0.9755693267738845[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    4.7s remaining:   21.3s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    6.0s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    8.6s finished
#
# [2021-12-13 19:47:44] Features: 20/30 -- score: 0.9737915881983678[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    5.9s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    8.1s finished
#
# [2021-12-13 19:47:52] Features: 21/30 -- score: 0.9747185543423003[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    5.0s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    8.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    8.1s finished
#
# [2021-12-13 19:48:00] Features: 22/30 -- score: 0.9746340365800199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    4.7s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.7s finished
#
# [2021-12-13 19:48:06] Features: 23/30 -- score: 0.9728299802157658[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    4.7s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    5.3s finished
#
# [2021-12-13 19:48:11] Features: 24/30 -- score: 0.9728356658672329[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    4.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    4.5s finished
#
# [2021-12-13 19:48:16] Features: 25/30 -- score: 0.9736692062034248[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.1s finished
#
# [2021-12-13 19:48:20] Features: 26/30 -- score: 0.9756367427256697[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.8s finished
#
# [2021-12-13 19:48:24] Features: 27/30 -- score: 0.9755748821404545[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.2s finished
#
# [2021-12-13 19:48:27] Features: 28/30 -- score: 0.9736952147498332[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.8s finished
#
# [2021-12-13 19:48:30] Features: 29/30 -- score: 0.9719092331768389[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.6s finished
#
# [2021-12-13 19:48:33] Features: 30/30 -- score: 0.9684019660794503

# %%
df_forward_result=pd.DataFrame(data={'r2':r2_max_list,
                                    'feature_names':feature_max_list})

# %%
# 保存模型测试和测试结果到本地文件
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_4_逐步向前特征测试结果.xlsx')
df_forward_result.to_excel(writer)
writer.save()

# %%
df_forward_result
# Out:
#                                                    r2  \
# 0                                [0.9016914032231247]
# 1            [0.9016914032231247, 0.9147936008521561]
# 2   [0.9016914032231247, 0.9147936008521561, 0.921...
# 3   [0.9016914032231247, 0.9147936008521561, 0.921...
# 4   [0.9016914032231247, 0.9147936008521561, 0.921...
# 5   [0.9016914032231247, 0.9147936008521561, 0.921...
# 6   [0.9016914032231247, 0.9147936008521561, 0.921...
# 7   [0.9016914032231247, 0.9147936008521561, 0.921...
# 8   [0.9016914032231247, 0.9147936008521561, 0.921...
# 9   [0.9016914032231247, 0.9147936008521561, 0.921...
# 10  [0.9016914032231247, 0.9147936008521561, 0.921...
# 11  [0.9016914032231247, 0.9147936008521561, 0.921...
# 12  [0.9016914032231247, 0.9147936008521561, 0.921...
# 13  [0.9016914032231247, 0.9147936008521561, 0.921...
# 14  [0.9016914032231247, 0.9147936008521561, 0.921...
# 15  [0.9016914032231247, 0.9147936008521561, 0.921...
# 16  [0.9016914032231247, 0.9147936008521561, 0.921...
# 17  [0.9016914032231247, 0.9147936008521561, 0.921...
# 18  [0.9016914032231247, 0.9147936008521561, 0.921...
# 19  [0.9016914032231247, 0.9147936008521561, 0.921...
# 20  [0.9016914032231247, 0.9147936008521561, 0.921...
# 21  [0.9016914032231247, 0.9147936008521561, 0.921...
# 22  [0.9016914032231247, 0.9147936008521561, 0.921...
# 23  [0.9016914032231247, 0.9147936008521561, 0.921...
# 24  [0.9016914032231247, 0.9147936008521561, 0.921...
# 25  [0.9016914032231247, 0.9147936008521561, 0.921...
# 26  [0.9016914032231247, 0.9147936008521561, 0.921...
# 27  [0.9016914032231247, 0.9147936008521561, 0.921...
# 28  [0.9016914032231247, 0.9147936008521561, 0.921...
# 29  [0.9016914032231247, 0.9147936008521561, 0.921...
#
#                                         feature_names
# 0                                        [(单核细胞绝对值,)]
# 1                      [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁)]
# 2   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 3   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 4   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 5   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 6   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 7   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 8   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 9   [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 10  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 11  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 12  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 13  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 14  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 15  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 16  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 17  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 18  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 19  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 20  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 21  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 22  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 23  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 24  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 25  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 26  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 27  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 28  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...
# 29  [(单核细胞绝对值,), (单核细胞绝对值, 异甘草酸镁), (单核细胞绝对值, 异甘草酸镁...

# %% [markdown]
# ## 逐步向前绘图

# %%
df_forward_result =pd.read_excel(project_path +'/data/result/feature_engineering/df_4_逐步向前特征测试结果.xlsx')
if 'Unnamed: 0' in df_forward_result.columns:
    df_forward_result = df_forward_result.drop(['Unnamed: 0'], axis=1)

# %%
# 计算R2和MSE、RMSE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score,roc_auc_score,f1_score
# XGBoost模型
feature_col_list=[]
f1_list=[]
for i in range(df_forward_result.shape[0]):
    feature_list=str(df_forward_result.loc[i,'feature_names']).split('\'')
    feature_list=feature_list[1:-1:2]

    tran_x_select=tran_x_sm[feature_list]
    test_x_select=test_x[feature_list]
    # 列出参数列表
    tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
    # 进行参数的搜索组合
    grid = GridSearchCV(RandomForestClassifier(),param_grid=tree_grid_parameter,cv=3)
    #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
    #根据已有数据去拟合随机森林模型
    grid.fit(tran_x_select, tran_y_sm)
    rfr = RandomForestClassifier(n_estimators=grid.best_params_['n_estimators'])
    rfr.fit(tran_x_select, tran_y_sm)
    predictions=rfr.predict(test_x_select)

    # 检验指标
    f1 = roc_auc_score(test_y,predictions)
    feature_col_list.append(feature_list)
    f1_list.append(f1)
    print('f1: ',f1)
# Out:
# f1:  0.6313186813186812
# f1:  0.6747252747252748
# f1:  0.6989010989010989
# f1:  0.723076923076923
# f1:  0.7192307692307691
# f1:  0.7587912087912088
# f1:  0.778021978021978
# f1:  0.8137362637362637
# f1:  0.8098901098901098
# f1:  0.8137362637362637
# f1:  0.8494505494505495
# f1:  0.8494505494505495
# f1:  0.8851648351648351
# f1:  0.8851648351648351
# f1:  0.8851648351648351
# f1:  0.8851648351648351
# f1:  0.9565934065934066
# f1:  0.9565934065934066
# f1:  0.9208791208791209
# f1:  0.9565934065934066
# f1:  0.9565934065934066
# f1:  0.9565934065934066
# f1:  0.9565934065934066
# f1:  0.9208791208791209
# f1:  0.8494505494505495
# f1:  0.8494505494505495
# f1:  0.8851648351648351
# f1:  0.8851648351648351
# f1:  0.8494505494505495
# f1:  0.8851648351648351

# %%
df_f1=pd.DataFrame(data={'feature_list':feature_col_list,
                        'f1':f1_list})
df_f1.to_excel(project_path+'/f1.xlsx')

# %%
# 画图
import matplotlib.pyplot as plt
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei']  ##绘图显示中文
mpl.rcParams['axes.unicode_minus'] = False

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import rc
rc('mathtext', default='regular')

# r2折线图
# 分辨率参数-dpi，画布大小参数-figsize
plt.figure(figsize=(30,10))
plt.plot(list(range(len(f1_list))),f1_list,
         color=(0.32941176470588235, 0.7294117647058823, 0.7490196078431373), label='AUC',linewidth=3) # 线粗细
# 设置坐标刻度值的大小
plt.tick_params(labelsize=23)

# 设置横纵坐标的名称以及对应字体格式
font_x = {'family': 'Times New Roman',
         'weight': 'normal',
         'size': 30,
         }
plt.xlabel('Number of Ranked features',font_x)
plt.ylabel('AUC',font_x)

# 展示横坐标
# x_list=list(df_feature['特征'])
# plt.xticks(list(range(len(f1_list))),f1_list,rotation=285)
# plt.legend(bbox_to_anchor=(1.1,1))  # 显示图例
# Out:
# Text(0, 0.5, 'AUC')

# %%
# 判断图片保存路径是否存在，否则创建
jpg_path = project_path + "/jpg"
mkdir(jpg_path)
plt.savefig(jpg_path + "/逐步向前rf_model2折线图.png", dpi=300)
plt.clf()  # 删除前面所画的图roc_auc_scoreroc_auc_scoreroc_auc_scoreroc_auc_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-e8ff699d1476> in <module>
#       1 # 判断图片保存路径是否存在，否则创建
#       2 jpg_path = project_path + "/jpg"
# ----> 3 mkdir(jpg_path)
#       4 plt.savefig(jpg_path + "/逐步向前rf_model2折线图.png", dpi=300)
#       5 plt.clf()  # 删除前面所画的图roc_auc_scoreroc_auc_scoreroc_auc_scoreroc_auc_score
#
# NameError: name 'mkdir' is not defined

# %% [markdown]
# ## 保存逐步向前筛选的建模数据

# %%
f1_max_index=f1_list.index(max(f1_list))
print(f1_max_index)
feature_com_best=df_forward_result.loc[f1_max_index,'feature_names']
# Out:
# 16

# %%
feature_list=str(feature_com_best).split('\'')
feature_forward_select=feature_list[1:-1:2]
feature_forward_select=['单核细胞绝对值','异甘草酸镁','甘草酸苷','托烷司琼','谷胱甘肽','红细胞','嗜酸性细胞百分比','多烯磷脂酰',
                        '嗜碱性细胞百分比','gender','RBC平均容量','MTX_tdm_72h','白蛋白(干式)','中性细胞百分比','MTX_tdm_48h',
                        '长春新碱','RBC血红浓度']
feature_forward_select.insert(0,'bmd_label')

# %%
feature_forward_select
# Out:
# ['bmd_label',
#  '单核细胞绝对值',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '嗜碱性细胞百分比',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜碱性细胞百分比',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜碱性细胞百分比',
#  'gender',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  'MTX_tdm_48h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  'MTX_tdm_48h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜酸性细胞百分比',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  'MTX_tdm_48h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜酸性细胞百分比',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  '中性细胞百分比',
#  'MTX_tdm_48h',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '嗜酸性细胞百分比',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  '中性细胞百分比',
#  'MTX_tdm_48h',
#  'RBC血红浓度',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '红细胞',
#  '嗜酸性细胞百分比',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  '中性细胞百分比',
#  'MTX_tdm_48h',
#  'RBC血红浓度',
#  '单核细胞绝对值',
#  '异甘草酸镁',
#  '甘草酸苷',
#  '托烷司琼',
#  '谷胱甘肽',
#  '红细胞',
#  '嗜酸性细胞百分比',
#  '多烯磷脂酰',
#  '嗜碱性细胞百分比',
#  'gender',
#  'RBC平均容量',
#  'MTX_tdm_72h',
#  '白蛋白(干式)',
#  '中性细胞百分比',
#  'MTX_tdm_48h',
#  '长春新碱',
#  'RBC血红浓度']

# %%
df_model_forward=df_model_importance[feature_forward_select]
df_model_forward.to_excel(project_path+'/data/result/df_model_data_forward.xlsx')
